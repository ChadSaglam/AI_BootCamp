# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./Day 4 Students files/hr_data.csv')

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.tail()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
df.sample(5)
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 268   45  Travel_Rarely       1385  Research & Development                20
# 360   57  Travel_Rarely        593  Research & Development                 1
# 137   39  Travel_Rarely       1329                   Sales                 4
# 649   53  Travel_Rarely        102  Research & Development                23
# 686   41  Travel_Rarely        263  Research & Development                 6
#
#      Education EducationField  EmployeeCount  EmployeeNumber  \
# 268          2        Medical              1             372
# 360          4        Medical              1             482
# 137          4  Life Sciences              1             182
# 649          4  Life Sciences              1             901
# 686          3        Medical              1             957
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# ### Data Visulations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1470, 35)

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1020
# Yes     185
# Name: count, dtype: int64

# %%
ax=sns.countplot(x=df['Attrition'])
ax.bar_label(ax.containers[0]);

# %%
ax=sns.countplot(x=df['Education'])
ax.bar_label(ax.containers[0]);

# %%
ax=sns.countplot(x=df['Gender'])
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### Feature Enginering

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df[['Attrition']]
# Out:
#      Attrition
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4           No
# ...        ...
# 1465       NaN
# 1466        No
# 1467        No
# 1468        No
# 1469        No
#
# [1470 rows x 1 columns]

# %%
d = {"Yes":1, "No": 0}

# %%
df['Attrition'] = df['Attrition'].map(d)

# %%
df[['Attrition']].value_counts()
# Out:
# Attrition
# 0.0          1020
# 1.0           185
# Name: count, dtype: int64

# %%
# df['Attrition'] = df['Attrition'].astype('int64')

# %%
empty = df[df['Attrition'].isnull()]
not_empty = df[df['Attrition'].notnull()]

# %%
empty.head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 367   50  Travel_Rarely       1046  Research & Development                10
# 368   40  Travel_Rarely        575                   Sales                22
# 369   31  Travel_Rarely        408  Research & Development                 9
# 370   21  Travel_Rarely        156                   Sales                12
# 371   29  Travel_Rarely       1283  Research & Development                23
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  \
# 367          3  Technical Degree              1             491
# 368          2         Marketing              1             492
# 369          4     Life Sciences              1             493
# 370          3     Life Sciences              1             494
# 371          3     Life Sciences              1             495
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
not_empty.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
x=not_empty.drop('Attrition', axis=1)
y=not_empty['Attrition']

# %%
x.sample(5)
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 314   39      Travel_Rarely        117  Research & Development
# 125   26      Travel_Rarely        841  Research & Development
# 407   45      Travel_Rarely        192  Research & Development
# 90    40  Travel_Frequently        530  Research & Development
# 568   55      Travel_Rarely        725  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 314                10          1        Medical              1
# 125                 6          3          Other              1
# 407                10          2  Life Sciences              1
# 90                  1          4  Life Sciences              1
# 568                 2          3        Medical              1
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 314             429                        3    Male          99
# 125             164                        3  Female          46
# ...

# %%
x.shape
# Out:
# (1205, 34)

# %%
x['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        845
# Travel_Frequently    235
# Non-Travel           125
# Name: count, dtype: int64

# %%
sns.countplot(x=df['EducationField'])
plt.xticks(rotation=90);

# %%
x=pd.get_dummies(x, drop_first=True)

# %%
x.shape
# Out:
# (1205, 46)

# %%
x.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Create Test datas 
# %80 for Education %20 for Testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Modeling

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

# %%
g= GaussianNB()
b=BernoulliNB()

# %%
g.fit(x_train,y_train)
b.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
guess1=g.predict(x_test)
guess2=b.predict(x_test)

# %%
# Classification Accuracy, Confusion Matrix, Precision, Recall, F1 Score

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(guess1, y_test)
# Out:
# 0.7883817427385892

# %%
confusion_matrix(guess1, y_test)
# Out:
# array([[171,  11],
#        [ 40,  19]])

# %%
print(classification_report(guess1, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.94      0.87       182
#          1.0       0.63      0.32      0.43        59
#
#     accuracy                           0.79       241
#    macro avg       0.72      0.63      0.65       241
# weighted avg       0.77      0.79      0.76       241

# %%
sns.heatmap(confusion_matrix(guess1, y_test), annot=True)
# Out:
# <Axes: >

# %%
accuracy_score(guess2, y_test)
# Out:
# 0.8257261410788381

# %%
confusion_matrix(guess2, y_test)
# Out:
# array([[192,  23],
#        [ 19,   7]])

# %%
sns.heatmap(confusion_matrix(guess2, y_test), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()

# %%
l.fit(x_train,y_train);

# %%
guess4=l.predict(x_test)

# %%
accuracy_score(guess4,y_test)
# Out:
# 0.8672199170124482

# %%
confusion_matrix(guess4,y_test)
# Out:
# array([[209,  30],
#        [  2,   0]])

# %%
print(classification_report(guess4, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.93       239
#          1.0       0.00      0.00      0.00         2
#
#     accuracy                           0.87       241
#    macro avg       0.50      0.44      0.46       241
# weighted avg       0.98      0.87      0.92       241

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
#owerfitting - undercutting ???
# Out:
# DecisionTreeClassifier()

# %%
guess5=d.predict(x_test)

# %%
accuracy_score(guess5,y_test)
# Out:
# 0.7759336099585062

# %%
confusion_matrix(guess5,y_test)
# Out:
# array([[180,  23],
#        [ 31,   7]])

# %%
print(classification_report(guess5, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87       203
#          1.0       0.23      0.18      0.21        38
#
#     accuracy                           0.78       241
#    macro avg       0.54      0.54      0.54       241
# weighted avg       0.76      0.78      0.76       241

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier()

# %%
r.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
guess6=r.predict(x_test)

# %%
accuracy_score(guess6,y_test)
# Out:
# 0.8879668049792531

# %%
confusion_matrix(guess6,y_test)
# Out:
# array([[211,  27],
#        [  0,   3]])

# %%
print(classification_report(guess6, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94       238
#          1.0       0.10      1.00      0.18         3
#
#     accuracy                           0.89       241
#    macro avg       0.55      0.94      0.56       241
# weighted avg       0.99      0.89      0.93       241

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()

# %%
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
guess7=gb.predict(x_test)

# %%
accuracy_score(guess7,y_test)
# Out:
# 0.8879668049792531

# %%
confusion_matrix(guess7,y_test)
# Out:
# array([[208,  24],
#        [  3,   6]])

# %%
print(classification_report(guess7, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.94       232
#          1.0       0.20      0.67      0.31         9
#
#     accuracy                           0.89       241
#    macro avg       0.59      0.78      0.62       241
# weighted avg       0.96      0.89      0.92       241

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()

# %%
k.fit(x_train,y_train);

# %%
guess3=k.predict(np.array(x_test))

# %%
accuracy_score(guess3,y_test)
# Out:
# 0.8547717842323651

# %%
confusion_matrix(guess3,y_test)
# Out:
# array([[205,  29],
#        [  6,   1]])

# %%
print(classification_report(guess3, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.88      0.92       234
#          1.0       0.03      0.14      0.05         7
#
#     accuracy                           0.85       241
#    macro avg       0.50      0.51      0.49       241
# weighted avg       0.94      0.85      0.90       241

# %%
x.shape
# Out:
# (1205, 46)

# %%
x.shape
# Out:
# (1205, 46)

# %%
empty
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 367    50      Travel_Rarely       1046  Research & Development
# 368    40      Travel_Rarely        575                   Sales
# 369    31      Travel_Rarely        408  Research & Development
# 370    21      Travel_Rarely        156                   Sales
# 371    29      Travel_Rarely       1283  Research & Development
# ...   ...                ...        ...                     ...
# 1461   50      Travel_Rarely        410                   Sales
# 1462   39      Travel_Rarely        722                   Sales
# 1463   31         Non-Travel        325  Research & Development
# 1464   26      Travel_Rarely       1167                   Sales
# 1465   36  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 367                 10          3  Technical Degree              1
# ...

# %%
x=empty.drop('Attrition',axis=1)

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
empty["Attrition"]=gb.predict(x)

# %%
d={0.0:'No',1.0:"Yes"}

# %%
empty["Attrition"]=empty["Attrition"].map(d)

# %%
empty
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 367    50      Travel_Rarely       1046  Research & Development
# 368    40      Travel_Rarely        575                   Sales
# 369    31      Travel_Rarely        408  Research & Development
# 370    21      Travel_Rarely        156                   Sales
# 371    29      Travel_Rarely       1283  Research & Development
# ...   ...                ...        ...                     ...
# 1461   50      Travel_Rarely        410                   Sales
# 1462   39      Travel_Rarely        722                   Sales
# 1463   31         Non-Travel        325  Research & Development
# 1464   26      Travel_Rarely       1167                   Sales
# 1465   36  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 367                 10          3  Technical Degree              1
# ...

# %%
# Support Vector Machine

# %%
#IRIS Data Set

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.countplot(df["species"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 sns.countplot(df["species"])
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
sns.pairplot(df,hue="species")

# %%
from sklearn.svm import SVC

# %%
s=SVC()

# %%
x=df.drop("species",axis=1)
y=df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
pred=s.fit(x_train,y_train).predict(x_test) # Trained and guessed

# %%
confusion_matrix(y_test,pred)

# %%
df.head()

# %%
s.predict([[5.1,3.5,1.4,0.2]])

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Modelleri tanımlayalım
g = GaussianNB()
b = BernoulliNB()
l = LogisticRegression()
d = DecisionTreeClassifier()
r = RandomForestClassifier()
gb= GradientBoostingClassifier()
kn= KNeighborsClassifier()

# Toplu Classification Model Eğitimi Fonksiyonu
def classification_fun(x, y):
    modeller=[g, b, l, d, r, gb, kn]
    isimler=["GaussianNB", "BernoulliNB", "LogisticRegression", "DecisionTreeClassifier", 
             "RandomForestClassifier", "GradientBoostingClassifier", "KNeighborsClassifier"]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state = 42)
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
    mdl=[]

    for model in modeller:
        model=model.fit(x_train,y_train)
        tahmin=model.predict(np.array(x_test) if model==kn else x_test)
        mdl.append(model)
        accuracy.append(accuracy_score(tahmin, y_test))
        precision.append(precision_score(tahmin, y_test))
        recall.append(recall_score(tahmin, y_test))
        f1.append(f1_score(tahmin, y_test))
        
    metrics=pd.DataFrame(columns=["Accuracy", "Precision", "Recall", "F1", "Model"], index=isimler)
    metrics["Accuracy"] = accuracy
    metrics["Precision"] = precision  
    metrics["Recall"] = recall
    metrics["F1"] = f1
    metrics["Model"]=mdl

    metrics.sort_values("F1", ascending=False, inplace=True)

    print("The most successful model: ", metrics.iloc[0].name)
    print(classification_report(metrics.iloc[0,-1].predict(x_test), y_test))
    
    return metrics.drop("Model", axis=1)

# %%
classification_fun(x_train,y_train)

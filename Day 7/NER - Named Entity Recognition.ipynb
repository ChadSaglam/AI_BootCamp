# %%
# Identifying the names of places, people and organizations mentioned in an article

# %% [raw]
# NLP - Ceviri
# Lang Detect
# POS - Part of Speech
# Sentiment Analizi
# Text Classification
# Text Generation - LSTM Long Short Time Memory
# Text Summarization Özet çikarma
# NER - Named Entity Recognition
# Topic Modelling - Hangi Konuda konusuldugunu anlatir

# %%
#pip install -U spacy
# Out:
# ...
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/06/80/c3b6b5b2e81ea2ea90054b6918bbfb1e8d20dc2570ae9e97a9f2744cf372/spacy-3.7.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata
# ...
#   Obtaining dependency information for spacy-legacy<3.1.0,>=3.0.11 from https://files.pythonhosted.org/packages/c3/55/12e842c70ff8828e34e543a2c7176dac4da006ca6901c9e8b43efab8bc6b/spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/05/29/5f48eea8712697f66531c4b6018b1713a3aec2b4eddbce1c63f93adbf6b1/murmurhash-1.0.10-cp311-cp311-macosx_10_9_x86_64.whl.metadata
# ...

# %%
import spacy
from spacy import displacy
NER=spacy.load('en_core_web_sm')

# %%
text="""Zafer Acar loves NLP and artificial intelligence. Python is a great programming language.
The Turkish Space Agency is the national space agency of Turkey, headquartered in Ankara.
It operates under the Departmet of Space which is direct overseen
by the President of Turkey and administor of TUA is Serdar Hüseyin Yildirim."""

# %%
text1=NER(text)

# %%
for word in text1.ents:
    print(word.text, word.label_)
# Out:
# Zafer Acar PERSON
# NLP ORG
# The Turkish Space Agency ORG
# Turkey GPE
# Ankara GPE
# the Departmet of Space ORG
# Turkey GPE
# TUA ORG
# Serdar Hüseyin Yildirim PERSON

# %%
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain('PERSON')
# Out:
# 'People, including fictional'

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %%
displacy.render(text1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1250e0d1641745459600f3361c558d48-0" class="displacy" width="9500" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Zafer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Acar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
displacy.render(text1, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zafer Acar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and artificial intelligence. Python is a great programming language.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Turkish Space Agency
# ...

# %% [markdown]
# <img src='./Day 7 Students files/Bacchanal-Buffet.jpg'>

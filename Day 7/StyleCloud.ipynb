# %%
# !pip install stylecloud
# pip install --upgrade stylecloud
# Out:
# ...
#   Using cached stylecloud-0.5.2-py3-none-any.whl
# ...
#   Attempting uninstall: stylecloud
#     Found existing installation: stylecloud 0.4
#     Uninstalling stylecloud-0.4:
#       Successfully uninstalled stylecloud-0.4
# ...

# %%
import stylecloud as sc

# %%
sc.gen_stylecloud(file_path='./Day 7 Students files/challenge.txt', output_name='./Day 7 Students files/ch.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sc.gen_stylecloud(file_path='./Day 7 Students files/challenge.txt', output_name='./Day 7 Students files/ch.png')
#
# File ~/anaconda3/lib/python3.11/site-packages/stylecloud/stylecloud.py:218, in gen_stylecloud(text, file_path, size, icon_name, palette, colors, background_color, max_font_size, max_words, stopwords, custom_stopwords, add_stopwords, icon_dir, output_name, gradient, font_path, random_state, collocations, invert_mask, pro_icon_path, pro_css_path)
#     215 if file_path:
#     216     text = file_to_text(file_path)
# --> 218 gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#     220 if gradient and colors is None:
#     221     pal_colors, mask_array = gen_gradient_mask(
#     222         size, palette, icon_dir, gradient, invert_mask
#     223     )
#
# ...

# %%
from IPython.display import Image
Image('./Day 7 Students files/wc.png')

# %%
sc.gen_stylecloud(file_path='./Day 7 Students files/challenge.txt',
                  icon_name='fas fa-dog',
                  background_color='white'
                  output_name='./Day 7 Students files/ch1.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sc.gen_stylecloud(file_path='./Day 7 Students files/challenge.txt',
#       2                   icon_name='fas fa-dog',
#       3                   output_name='./Day 7 Students files/ch.png')
#
# File ~/anaconda3/lib/python3.11/site-packages/stylecloud/stylecloud.py:218, in gen_stylecloud(text, file_path, size, icon_name, palette, colors, background_color, max_font_size, max_words, stopwords, custom_stopwords, add_stopwords, icon_dir, output_name, gradient, font_path, random_state, collocations, invert_mask, pro_icon_path, pro_css_path)
#     215 if file_path:
#     216     text = file_to_text(file_path)
# --> 218 gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#     220 if gradient and colors is None:
#     221     pal_colors, mask_array = gen_gradient_mask(
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Load the text from the file
with open('./Day 7 Students files/challenge.txt', 'r') as file:
    text = file.read()

# Generate the word cloud image
wordcloud = WordCloud().generate(text)

# Display the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# Save the word cloud image
wordcloud.to_file('./Day 7 Students files/ch.png');

# %%
# https://github.com/minimaxir/stylecloud/issues/31
